# %%
from llama_index.core import Settings
from llama_index.embeddings.openai import OpenAIEmbedding

embed_model = OpenAIEmbedding(
            model='text-embedding-3-small',
            api_key="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",
        )

Settings.embed_model = embed_model

# %%
from llama_index.vector_stores.weaviate import WeaviateVectorStore
from llama_index.core import VectorStoreIndex
import weaviate

# Connect to Weaviate
client = weaviate.connect_to_local()  # or your Weaviate URL

# Load vector store
vector_store = WeaviateVectorStore(weaviate_client=client, index_name="DSC2024")

# Load index
index = VectorStoreIndex.from_vector_store(vector_store)

# # Check all nodes (documents/chunks)
# nodes = index.vector_store.get_all()
# for node in nodes:
#     print(node.node_id, node.get_text())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22036\525985247.py:9: ResourceWarning: Unclosed MongoClient opened at:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\ASUS\anaconda3\envs\chatbotsaudh\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\ASUS\anaconda3\envs\chatbotsaudh\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\ASUS\anaconda3\envs\chatbotsaudh\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\ASUS\anaconda3\envs\chatbotsaudh\Lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\ASUS\anaconda3\envs\chatbotsaudh\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
# ...

# %%
from llama_index.core.retrievers import VectorIndexAutoRetriever, VectorIndexRetriever

retriever = VectorIndexRetriever(index=index, similarity_top_k=10)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22036\2077046157.py:3: ResourceWarning: unclosed <socket.socket fd=7804, family=23, type=1, proto=0, laddr=('::1', 55586, 0, 0), raddr=('::1', 8080, 0, 0)>
#   retriever = VectorIndexRetriever(index=index, similarity_top_k=10)
# ...

# %%
retriever.retrieve("học phí học thạc sĩ trường uit là bao nhiê")
# Out:
# [NodeWithScore(node=TextNode(id_='3b7afa58-d1ce-4d39-b4d3-c2b8da8ac321', embedding=[-0.021014487370848656, -0.006284109316766262, 0.004100647754967213, -0.044052671641111374, 0.052360475063323975, -0.025349458679556847, -0.01458126399666071, 0.03389158472418785, -0.013303140178322792, -0.039856165647506714, -0.008488873019814491, -0.0023805059026926756, -0.06467307358980179, -0.008877635933458805, 0.03231523185968399, 0.026222841814160347, -0.023325761780142784, -0.020716259256005287, -0.03691647946834564, 0.010326175950467587, 0.027820497751235962, -0.032592158764600754, 0.03048325516283512, 0.022708002477884293, 0.03199570253491402, -0.045671626925468445, 0.019991988316178322, 0.007727324031293392, -0.029141224920749664, 0.02965247444808483, 0.008994797244668007, -0.02309143915772438, 0.005602443125098944, 0.0062202028930187225, -0.006747429259121418, 0.06348015367984772, -0.016455845907330513, 0.06991337984800339, -0.015092513523995876, -0.051934435963630676, 0.0049500674940645695
# ...

# %%
import weaviate

client = weaviate.connect_to_local()

nodes_info = client.cluster.nodes(
    output="verbose"  #  If omitted, will be "minimal"
)
print(nodes_info)
# Out:
# [Node(git_hash='6fd2432', name='node1', shards=[Shard(collection='SuggestionIndex', name='35SJRZO6uiGB', node='node1', object_count=0, vector_indexing_status='READY', vector_queue_length=0, compressed=False, loaded=True), Shard(collection='LlamaIndex_d6bbeefd4bb44eeca5ecbc1be61480d8', name='6uA1AwAP1AuC', node='node1', object_count=0, vector_indexing_status='READY', vector_queue_length=0, compressed=False, loaded=True), Shard(collection='LlamaIndex_a72970009af64369aaa3ff5a833f35ed', name='SaYfVaS2JsHf', node='node1', object_count=0, vector_indexing_status='READY', vector_queue_length=0, compressed=False, loaded=True), Shard(collection='MyIndex', name='n9x82PuaSaHB', node='node1', object_count=0, vector_indexing_status='READY', vector_queue_length=0, compressed=False, loaded=True), Shard(collection='DSC2024', name='NyMWXSvfvTDh', node='node1', object_count=1, vector_indexing_status='READY', vector_queue_length=0, compressed=False, loaded=True)], stats=Stats(object_count=1, shard_count
# ...

# %%
len(nodes_info)
# Out:
# 1

# %%
from llama_index.core import SimpleDirectoryReader

documents = await SimpleDirectoryReader(
                input_files=["data/cam_nang_sau_dai_hoc_thac_si_truong_uit.pdf"]
            ).aload_data()

# %%
len(documents)
# Out:
# 138

# %%
import sys
import os

# Add the parent directory of 'src' to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.storage.weaviatedb import WeaviateDB

vector_store = WeaviateDB(host="localhost")

# %%
await vector_store.add_knowledge_by_chunking(
    file_name="cam_nang_sau_dai_hoc_thac_si_truong_uit.pdf",
    file_type="pdf",
    public_id="cam_nang_sau_dai_hoc_thac_si_truong_uit",
    documents=documents,

)
# Out:
# Tiêu đề: cẩm nang sau đại học thạc sĩ trường uit
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 await vector_store.add_knowledge_by_chunking(
#       2     file_name="cam_nang_sau_dai_hoc_thac_si_truong_uit.pdf",
#       3     file_type="pdf",
#       4     public_id="cam_nang_sau_dai_hoc_thac_si_truong_uit",
#       5     documents=documents,
#       6
#       7 )
#
# File ~/uit_chatbot/src/storage/weaviatedb.py:489, in WeaviateDB.add_knowledge_by_chunking(self, url, file_type, public_id, file_name, documents)
#     486     node.text = f"Tiêu đề: {vietnamese_title.text}\n{node.text}"
#     488 self.insert_nodes(nodes=nodes)
# --> 489 self.insert_docstore(nodes=nodes)
#
# File ~/uit_chatbot/src/storage/weaviatedb.py:400, in WeaviateDB.insert_docstore(self, nodes)
#     389 """
#     390 Inserts a list of TextNode objects into the document store.
# ...
